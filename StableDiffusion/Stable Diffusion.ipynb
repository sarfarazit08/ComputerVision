# %% [markdown]
# What We need
#
# 1. Google Drive with 15 GB of space
# 2. Hugging Face Account (Access Token)
# 3. Google Colab Notebook
#
# [Stable Diffusion](https://github.com/camenduru/stable-diffusion-webui-colab/tree/drive)
